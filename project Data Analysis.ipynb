# %% [markdown]
# ## DataSet Sample super store
#
# First project Data Analysis

# %% [markdown]
# # Statement:
# Perform Exploratory Data Analysis on dataset ‘SampleSuperstore’ As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# # Project covered Tech Topic:
#
# ######  Pandas read/write func.
# ######  head/tail.
# ######  Data decription or summary report
# ######  Data information or datatypes info
# ######  Data Processing
# ######  distinct/unique operation
# ######  Duplicates Analysis
# ######  Data Correlation Analysis, content writing, ploting throught Heatmap
# ######  Data Coveriance
# ######  Exploratory Data Analysis (EDA)
# ######  Drop unwanted & correlated correlation.
# ######  Pivot Analysis
# ######  Data Summarization report
# ######  Plotting:
#     Bar Graph
#     Line Graph
#     Scatter Graph
#     Count plot
#     Factor plot
#     Box plot

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read Dataset file

# %%
dataset = pd.read_csv(r"C:\Users\RAJAT SAHU\Desktop\DataScirce\Superstore.csv",encoding= 'unicode_escape')

# %% [markdown]
# ### Data top value (For basic understanding)

# %%
dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dataset.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Basic info about the data
#
#     Null value finding
#     Basic understandng of Data Type

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # Data description
#     count :  Total value count
#     means :  Avg of total value
#     std :    standred deviation
#     min :    Minimum value of the column dataset
#     25% :    Q1-quantile
#     50% :    Q2-Median of the value
#     75% :    Q3-Mode of the value
#     Max :    Maximum value of the column dataset

# %%
dataset.describe(include='number')
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # Observation:
#     For sales mean > median, it tells us that is positively skwed.
#     For Quatity mean ~ median, it tells us that it is normally distributed.
#     For Profit mean > median, it tells us that it is positively distributed.
#     For Sales mean > median, it tells us that it is positively distributed.

# %% [markdown]
# # Data Preprocessing

# %%
#Null value finding
dataset.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# There is no null value otherwise we have to replace to the #mean value or drop the same column.

# %% [markdown]
# # Find the distinct dataset numbers

# %%
# unique values in the dataset
dataset.nunique()
# Out:
# Row ID           9994
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# dtype: int64

# %% [markdown]
# # Find duplicates values and drop them

# %%
# find duplicated vale in the database
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates value otherwise we have to remove all duplicate using mentioned command : dataset.drop_duplicates()

# %% [markdown]
# # Find the correlation of dataset

# %%
# correlation between the Numeric dataset
dataset.corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# # Observation:
#     The correlation value between the values ​​is clearly 100%. If the correlated value is more than 50% then we should remove it from the best accuracy model.

# %%
#correlation data based heatmap and annot data.
plt.figure(figsize=(15,5))
sns.heatmap(dataset.corr(),cmap='rocket_r',annot=True)
plt.show()

# %% [markdown]
# # Observation:
#     In psychological research, we use Cohen's (1988) conventions to interpret effect size. A correlation coefficient of .10 is thought to represent a weak or small association; a correlation coefficient of .30 is considered a moderate correlation; and a correlation coefficient of .50 or larger is thought to represent a strong or large correlation.
#     Effect Size (Cohen)
#     .10    Small
#     .30    Moderate
#     .50    Large
#
#     Sales vs profit are Moderate correlation.
#     Discount vs Profit are Nogative small correlation.
#     Profit vs Sales are Moderate correlation.

# %% [markdown]
# # Find the covariance of dataset

# %%
#Data covariance
dataset.cov()
# Out:
#                    Row ID   Postal Code          Sales    Quantity  \
# Row ID       8.324169e+06  8.946577e+05   -2442.819776  -25.782598
# Postal Code  8.946577e+05  1.028080e+09 -476682.766590  910.415885
# Sales       -2.442820e+03 -4.766828e+05  388434.455308  278.459923
# Quantity    -2.578260e+01  9.104159e+02     278.459923    4.951113
# Discount     8.029358e+00  3.868704e+02      -3.627228    0.003961
# Profit       8.446585e+03 -2.250458e+05   69944.096586   34.534769
#
#                Discount         Profit
# Row ID         8.029358    8446.585421
# Postal Code  386.870404 -225045.849445
# Sales         -3.627228   69944.096586
# Quantity       0.003961      34.534769
# Discount       0.042622     -10.615173
# Profit       -10.615173   54877.798055

# %% [markdown]
# # Observation:

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
sns.pairplot(dataset,size=3)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data1 = dataset.drop('Postal Code',axis=1)

# %%
data1.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar('Category','Sub-Category',data=data1)
plt.show()

# %% [markdown]
# # Observation Bar plot:
#     Technology is the highest demand categories and Furniture is the lowest
#
#      Below Plot:
#      in Technology top 4 items are : phone, Accessiories, Machine, Copers.

# %%
plt.figure(figsize=(20,5))
plt.bar('Sub-Category','Category',data=data1)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='State',data=data1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation:
#     Calofonia is the Top sales State

# %%
uq= data1['State'].unique()
uq
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
## Find Top city in sales of the california.
data1.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State Region  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky  South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136

# %%
data1.groupby(['State','City'],sort=False)['Sales','Profit'].sum()
# Out:
# <ipython-input-27-6755ecc7ec48>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data1.groupby(['State','City'],sort=False)['Sales','Profit'].sum()
#                                       Sales      Profit
# State          City
# Kentucky       Henderson         15661.0100   4518.8169
# California     Los Angeles      175851.3410  30440.7579
# Florida        Fort Lauderdale    4929.5325   -161.3551
# North Carolina Concord            5111.8440  -1788.6868
# Washington     Seattle          119540.7420  29156.0967
# ...                                     ...         ...
# Arkansas       Springdale            4.3000      1.4190
# California     Lodi                136.9800     44.4858
# Texas          La Porte             30.3920    -32.5272
# Ohio           Mason                94.2640     -4.2352
# Georgia        Woodstock           286.6500    104.8788
#
# [604 rows x 2 columns]

# %% [markdown]
# # Observation:
#     Top1: Profit and Sales is high in State-California and City-Los Angeles
#     Top2: State-Washington and City-Seattle

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Sub-Category',data=data1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Category',data=data1)
plt.show()

# %%
data1.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State Region  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky  South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Region',data=data1)
plt.show()

# %% [markdown]
# # Observation:
#     West region best for the sales and Superstore

# %% [markdown]
# # Analysis of profit and Sales by ship mode and categories

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Ship Mode',y='Profit',hue='Category',kind='bar',data=data1)
plt.show()
# Out:
# C:\Users\RAJAT SAHU\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Observation:
#     Ship mode of the first class has highest profit
#     and Technology share has highest profit

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Region',y='State',data=data1)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Ship Mode',y='Sales',hue='Category',kind='bar',data=data1)
plt.show()
# Out:
# C:\Users\RAJAT SAHU\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Observation:
#     Highest Sales share by Technology categories.

# %% [markdown]
# # Analysis of Profit and Sales by Region

# %%
plt.figure(figsize=(8,5))
sns.factorplot(x='Ship Mode',y='Profit',kind='bar',data=data1)
plt.show()
# Out:
# C:\Users\RAJAT SAHU\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
data1.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State Region  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky  South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136

# %%
data1.Segment.unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Segment',y='Profit',data=data1)
plt.show()

# %% [markdown]
# # Observation:
#     Hightes Profit in the Home Office Segment and lowes in the Cousumer
#     and sales also higest in the Home office Segment

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Segment',y='Sales',data=data1)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.boxplot('Profit',data=data1)
plt.subplot(122)
sns.lineplot(x='Sales',y='Profit',data=data1)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Observation:
#     Fig1 : We find the some outlier values and only 2 values are lies as a outlier when data is more then 6K
#     Fig2 : Mostly sale lies between the 0-5K. and profit was there Negative and Postivite as well.
#             but when Sale amount is high, we got these is high amount of profit and less negative profit value.
# Means we have to focus on the Sale but in hight amount and less no. of time.

# %%
data1.head(1)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State Region  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky  South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136

# %% [markdown]
# # Group by Summary report of the Sale Segment

# %%
DataGroup=data1.groupby(['Region','Segment','Country','City','State'])['Sales','Profit'].sum()
DataGroup
# Out:
# <ipython-input-54-84dc759290f4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   DataGroup=data1.groupby(['Region','Segment','Country','City','State'])['Sales','Profit'].sum()
#                                                                 Sales  \
# Region  Segment     Country       City         State
# Central Consumer    United States Aberdeen     South Dakota    25.500
#                                   Abilene      Texas            1.392
#                                   Allen        Texas          290.206
#                                   Amarillo     Texas         3548.082
#                                   Apple Valley Minnesota      137.940
# ...                                                               ...
# West    Home Office United States Tigard       Oregon         205.744
#                                   Tucson       Arizona        360.058
# ...

# %% [markdown]
# # Pivot table summary report analysis of Sales data

# %%
pd.pivot_table(data=data1,index=['Region','Segment','Country','City','State'],aggfunc={'Sales':np.sum,'Profit':np.sum})
# Out:
#                                                                Profit  \
# Region  Segment     Country       City         State
# Central Consumer    United States Aberdeen     South Dakota    6.6300
#                                   Abilene      Texas          -3.7584
#                                   Allen        Texas         -39.8775
#                                   Amarillo     Texas        -358.3643
#                                   Apple Valley Minnesota       8.9706
# ...                                                               ...
# West    Home Office United States Tigard       Oregon         14.2053
#                                   Tucson       Arizona       -17.5368
#                                   Vallejo      California    277.8048
#                                   Vancouver    Washington     11.4452
#                                   Yuma         Arizona      -515.8728
#
#                                                                 Sales
# ...

# %% [markdown]
# # Analysis Profit by Sub Categories

# %%
plt.figure(figsize=(20,50))
sns.factorplot(x='Sub-Category', y='Profit',kind='bar',data=data1)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Observation:
#     Copiers has a highest profit in data
#     Tables and Bookcases has loss
#     Art, Fasteners, Suppliers has almost Zero Profit (time to focus over on it)

# %% [markdown]
# # Analysis of profit by Discount

# %%
plt.figure(figsize=(10,5))
sns.lineplot('Discount','Profit',data=data1,label='Discount')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Observation:
#     When discount is less at that time profit also a less. we need retarget the user through Discount coupons
#
#     Discount ~ Profit (Profit is propotional to the Discount)

# %% [markdown]
# # Analysis Profit By city

# %%
#pd.pivot_table(data=data1,index=['State','City'].sort_values(by='Profit', ascending=False).index,aggfunc={'Profit':sum})
pd.pivot_table(data=data1,index=['State','City'],aggfunc={'Profit':sum})
# Out:
#                          Profit
# State     City
# Alabama   Auburn       452.6071
#           Decatur     1000.0881
#           Florence     248.6589
#           Hoover        18.7173
#           Huntsville  1005.2572
# ...                         ...
# Wisconsin Superior     514.0822
#           Waukesha      14.1700
#           Wausau        90.4306
#           West Allis    28.3708
# Wyoming   Cheyenne     100.1960
#
# [604 rows x 1 columns]

# %%
data_city=data1.groupby(['City'])[['Profit']].sum()
data_city = data_city.sort_values('Profit',ascending=False)
data_city
# Out:
#                    Profit
# City
# New York City  62036.9837
# Los Angeles    30440.7579
# Seattle        29156.0967
# San Francisco  17507.3854
# Detroit        13181.7908
# ...                   ...
# Chicago        -6654.5688
# Lancaster      -7239.0684
# San Antonio    -7299.0502
# Houston       -10153.5485
# Philadelphia  -13837.7674
#
# [531 rows x 1 columns]

# %% [markdown]
# # Observation:
#     Top 5 highest profit city in the database
#     New York City
#     Los Angeles
#     Seattle
#     San Francisco
#     Detroit
#
#     But if we will talk about the average profit of the sales then some intresing data we got.
#     Jamestown
#     Independence
#     Lafayette
#     Minneapolis
#     Appleton

# %%
data_city=data1.groupby(['City'])[['Profit']].mean()
data_city = data_city.sort_values('Profit',ascending=False)
data_city
# Out:
#                   Profit
# City
# Jamestown     642.885750
# Independence  487.831500
# Lafayette     323.173794
# Minneapolis   296.721070
# Appleton      277.383150
# ...                  ...
# Lancaster    -157.371052
# Round Rock   -169.061614
# Oswego       -178.709200
# Champaign    -182.352000
# Bethlehem    -200.619160
#
# [531 rows x 1 columns]

# %%
#1.Hightes Profit 20 city
data_city['Profit'].head(20).plot(kind='bar',figsize=(15,5),color = 'lightBlue')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
#1.Hightes Profit 20 city
data_city['Profit'].tail(20).plot(kind='bar',figsize=(15,5),color = 'DarkBlue')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Observation:
#     20 cities has a highes profit
#     20 cities has a Negative profit
#     Top Profit City is : Jamestown
#     Top Low profit City is  : Bethlehem
